# %%
# !pip install pyreadr
# Out:
# Collecting pyreadr
#   Downloading pyreadr-0.5.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyreadr) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->pyreadr) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->pyreadr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->pyreadr) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->pyreadr) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadr) (1.17.0)
# Downloading pyreadr-0.5.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (418 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.3/418.3 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: pyreadr
# Successfully installed pyreadr-0.5.3

# %%
import pandas as pd
import numpy as np
import pyreadr
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Load the .rds file
result = pyreadr.read_r('btc_features.rds')
data_df = result[None] # [None] is the default key for a single .rds object

# Convert date and set index
data_df['date'] = pd.to_datetime(data_df['date'])
data_df = data_df.set_index('date')

print(data_df.head())
# Out:
#                     open          high           low         close  \
# date
# 2018-02-19  10552.599609  11273.799805  10513.200195  11225.299805
# 2018-02-20  11231.799805  11958.500000  11231.799805  11403.700195
# 2018-02-21  11372.200195  11418.500000  10479.099609  10690.400391
# 2018-02-22  10660.400391  11039.099609   9939.089844  10005.000000
# 2018-02-23   9937.070312  10487.299805   9734.559570  10301.099609
#
#                   volume      adjusted  log_returns     rsi_14       sma_20  \
# date
# 2018-02-19  7.652090e+09  11225.299805     0.061874  57.789772  9103.446533
# 2018-02-20  9.926540e+09  11403.700195     0.015768  58.746797  9162.576563
# 2018-02-21  9.405340e+09  10690.400391    -0.064592  53.521679  9238.569580
# 2018-02-22  8.040080e+09  10005.000000    -0.066261  49.010805  9297.282080
# 2018-02-23  7.739500e+09  10301.099609     0.029166  50.934709  9353.591553
#
#                   sma_50      macd  macd_signal
# date
# 2018-02-19  11550.002637 -2.443717    -7.517337
# 2018-02-20  11504.932637 -1.093325    -6.232534
# 2018-02-21  11419.098652 -0.592388    -5.104505
# 2018-02-22  11315.178652 -0.728348    -4.229274
# 2018-02-23  11209.216641 -0.595588    -3.502536

# %%
# Create a copy to avoid warnings
df_scaled = data_df.copy()

# Log-transform volume to reduce its extreme scale
df_scaled['volume'] = np.log(df_scaled['volume'])

# We will scale ALL features between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df_scaled)

# We also need a separate scaler for JUST the 'close' price
# This is so we can inverse-transform our predictions back to dollars
scaler_close = MinMaxScaler(feature_range=(0, 1))
scaler_close.fit(data_df[['close']])
# Out:
# MinMaxScaler()

# %%
# We will use a "lookback" of 60 days
def create_dataset(dataset, look_back=60):
    X, Y = [], []
    for i in range(look_back, len(dataset)):
        # X is the 60 days of features
        X.append(dataset[i-look_back:i, :])
        # Y is the 61st day's 'close' price (which is at column index 4)
        Y.append(dataset[i, 4])
    return np.array(X), np.array(Y)

look_back = 60
num_features = scaled_data.shape[1]

# Create the full dataset
X_full, y_full = create_dataset(scaled_data, look_back)

# Split into train/test (80/20 split, same as R)
split_point = int(len(X_full) * 0.8)
X_train, X_test = X_full[:split_point], X_full[split_point:]
y_train, y_test = y_full[:split_point], y_full[split_point:]

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# X_train shape: (2202, 60, 12)
# y_train shape: (2202,)

# %%
# Build the LSTM Model
model_lstm = Sequential()
model_lstm.add(LSTM(units=50, return_sequences=True, input_shape=(look_back, num_features)))
model_lstm.add(Dropout(0.2))
model_lstm.add(LSTM(units=50, return_sequences=False))
model_lstm.add(Dropout(0.2))
model_lstm.add(Dense(units=25))
model_lstm.add(Dense(units=1)) # Output layer (predicts 1 value)

# Compile the model
model_lstm.compile(optimizer='adam', loss='mean_squared_error')

# Train the model (this will take a few minutes)
print("Training LSTM Model...")
model_lstm.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test))
print("LSTM Training complete.")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM Model...
# Epoch 1/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - loss: 0.0362 - val_loss: 0.0101
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0062 - val_loss: 0.0083
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0053 - val_loss: 0.0080
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.0050 - val_loss: 0.0075
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0046 - val_loss: 0.0090
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0045 - val_loss: 0.0109
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 0.0046 - val_loss: 0.0075
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0042 - val_loss: 0.0091
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0047 - val_loss: 0.0106
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.0045 - val_loss: 0.0072
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0041 - val_loss: 0.0072
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - loss: 0.0040 - val_loss: 0.0071
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 0.0039 - val_loss: 0.0072
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0040 - val_loss: 0.0071
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0040 - val_loss: 0.0074
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0036 - val_loss: 0.0073
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0037 - val_loss: 0.0072
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0038 - val_loss: 0.0080
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0039 - val_loss: 0.0072
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0036 - val_loss: 0.0073
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 0.0038 - val_loss: 0.0086
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0040 - val_loss: 0.0072
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 0.0037 - val_loss: 0.0074
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0037 - val_loss: 0.0072
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0038 - val_loss: 0.0071
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0038 - val_loss: 0.0073
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0039 - val_loss: 0.0071
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0038 - val_loss: 0.0073
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 0.0036 - val_loss: 0.0071
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 0.0034 - val_loss: 0.0073
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 0.0037 - val_loss: 0.0071
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.0033 - val_loss: 0.0091
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0040 - val_loss: 0.0072
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0036 - val_loss: 0.0070
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.0039 - val_loss: 0.0077
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0037 - val_loss: 0.0074
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 0.0035 - val_loss: 0.0069
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0033 - val_loss: 0.0078
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0035 - val_loss: 0.0070
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 0.0036 - val_loss: 0.0070
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0033 - val_loss: 0.0099
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.0036 - val_loss: 0.0068
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 0.0035 - val_loss: 0.0069
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0034 - val_loss: 0.0067
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0032 - val_loss: 0.0065
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0033 - val_loss: 0.0065
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0031 - val_loss: 0.0065
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0030 - val_loss: 0.0065
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.0033 - val_loss: 0.0062
# LSTM Training complete.

# %%
# Make predictions
predictions_scaled = model_lstm.predict(X_test)

# Inverse transform the predictions back to dollar amounts
predictions_lstm = scaler_close.inverse_transform(predictions_scaled)

# Save predictions to a CSV file
pred_df_lstm = pd.DataFrame(predictions_lstm, columns=['lstm_pred'])
pred_df_lstm.to_csv('lstm_predictions.csv', index=False)

print("LSTM predictions saved to 'lstm_predictions.csv'")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
# LSTM predictions saved to 'lstm_predictions.csv'

# %%
# Load the .rds file with the ARIMA residuals
result_resid = pyreadr.read_r('arimax_residuals.rds')
residuals = result_resid[None].values.flatten() # Get as a flat numpy array

print(f"Loaded {len(residuals)} residuals from ARIMAX model.")
# Out:
# Loaded 2250 residuals from ARIMAX model.

# %%
# We will use the same scaled features (df_scaled) from before,
# but our target (Y) is now the residuals.

# Scale the residuals
scaler_resid = MinMaxScaler(feature_range=(0, 1))
scaled_residuals = scaler_resid.fit_transform(residuals.reshape(-1, 1))

# Align features and residuals (residuals start after ARIMAX training)
aligned_features = scaled_data[len(scaled_data) - len(scaled_residuals):, :]

# Create the dataset for the hybrid model
def create_hybrid_dataset(features, residuals, look_back=60):
    X, Y = [], []
    for i in range(look_back, len(residuals)):
        X.append(features[i-look_back:i, :])
        Y.append(residuals[i, 0]) # Target is the residual
    return np.array(X), np.array(Y)

X_full_hybrid, y_full_hybrid = create_hybrid_dataset(aligned_features, scaled_residuals, look_back)

# Split into train/test
split_point_hybrid = int(len(X_full_hybrid) * 0.8)
X_train_hybrid, X_test_hybrid = X_full_hybrid[:split_point_hybrid], X_full_hybrid[split_point_hybrid:]
y_train_hybrid, y_test_hybrid = y_full_hybrid[:split_point_hybrid], y_full_hybrid[split_point_hybrid:]

print(f"X_train_hybrid shape: {X_train_hybrid.shape}")
# Out:
# X_train_hybrid shape: (1752, 60, 12)

# %%
# Build the Hybrid LSTM Model
model_hybrid = Sequential()
model_hybrid.add(LSTM(units=50, return_sequences=True, input_shape=(look_back, num_features)))
model_hybrid.add(Dropout(0.2))
model_hybrid.add(LSTM(units=50, return_sequences=False))
model_hybrid.add(Dropout(0.2))
model_hybrid.add(Dense(units=25))
model_hybrid.add(Dense(units=1))

# Compile
model_hybrid.compile(optimizer='adam', loss='mean_squared_error')

# Train
print("Training Hybrid (Residual) LSTM Model...")
model_hybrid.fit(X_train_hybrid, y_train_hybrid, batch_size=32, epochs=50, validation_data=(X_test_hybrid, y_test_hybrid))
print("Hybrid Training complete.")
# Out:
# Training Hybrid (Residual) LSTM Model...
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - loss: 0.0703 - val_loss: 0.0072
# Epoch 2/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0145 - val_loss: 0.0081
# Epoch 3/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0130 - val_loss: 0.0083
# Epoch 4/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 0.0120 - val_loss: 0.0065
# Epoch 5/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0120 - val_loss: 0.0106
# Epoch 6/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0112 - val_loss: 0.0084
# Epoch 7/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 0.0104 - val_loss: 0.0085
# Epoch 8/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0115 - val_loss: 0.0066
# Epoch 9/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0104 - val_loss: 0.0063
# Epoch 10/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0097 - val_loss: 0.0081
# Epoch 11/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.0098 - val_loss: 0.0079
# Epoch 12/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0095 - val_loss: 0.0108
# Epoch 13/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0101 - val_loss: 0.0067
# Epoch 14/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0096 - val_loss: 0.0093
# Epoch 15/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0101 - val_loss: 0.0069
# Epoch 16/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0101 - val_loss: 0.0075
# Epoch 17/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - loss: 0.0101 - val_loss: 0.0066
# Epoch 18/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0091 - val_loss: 0.0085
# Epoch 19/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0093 - val_loss: 0.0106
# Epoch 20/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0091 - val_loss: 0.0064
# Epoch 21/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0092 - val_loss: 0.0096
# Epoch 22/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0091 - val_loss: 0.0075
# Epoch 23/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 24/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0085 - val_loss: 0.0081
# Epoch 25/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0090 - val_loss: 0.0074
# Epoch 26/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 27/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0081 - val_loss: 0.0074
# Epoch 28/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0087 - val_loss: 0.0100
# Epoch 29/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0092 - val_loss: 0.0084
# Epoch 30/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.0089 - val_loss: 0.0085
# Epoch 31/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0085 - val_loss: 0.0067
# Epoch 32/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 0.0079 - val_loss: 0.0068
# Epoch 33/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0081 - val_loss: 0.0074
# Epoch 34/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - loss: 0.0082 - val_loss: 0.0061
# Epoch 35/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0087 - val_loss: 0.0068
# Epoch 36/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0082 - val_loss: 0.0060
# Epoch 37/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 0.0076 - val_loss: 0.0059
# Epoch 38/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0079 - val_loss: 0.0066
# Epoch 39/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 40/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0078 - val_loss: 0.0059
# Epoch 41/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 0.0079 - val_loss: 0.0062
# Epoch 42/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0074 - val_loss: 0.0060
# Epoch 43/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.0068 - val_loss: 0.0069
# Epoch 44/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 0.0085 - val_loss: 0.0060
# Epoch 45/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 0.0066 - val_loss: 0.0074
# Epoch 46/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 47/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 48/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0062 - val_loss: 0.0070
# Epoch 49/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 50/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0063 - val_loss: 0.0059
# Hybrid Training complete.

# %%
# 1. Predict the scaled residuals
predicted_scaled_residuals = model_hybrid.predict(X_test_hybrid)

# 2. Inverse-transform the residuals
predicted_residuals = scaler_resid.inverse_transform(predicted_scaled_residuals)

# 3. Load the ARIMAX forecast from R
# We need the ARIMAX test-set predictions. Let's upload that file.
# NOTE: Go back to RStudio, add this line to 03_modeling.R and re-run:
# saveRDS(as.vector(arimax_forecast$mean), here::here("output", "models", "arimax_test_forecast.rds"))
#
# Then, upload 'arimax_test_forecast.rds' to Colab.

# --- Once 'arimax_test_forecast.rds' is uploaded, run this ---
result_arimax_fc = pyreadr.read_r('arimax_test_forecast.rds')
arimax_forecast_values = result_arimax_fc[None].values.flatten()

# 4. Align the forecasts (they may have different start points)
len_arimax = len(arimax_forecast_values)
len_hybrid = len(predicted_residuals)

# Get the part of the ARIMAX forecast that aligns with the hybrid
aligned_arimax_forecast = arimax_forecast_values[len_arimax - len_hybrid:]

# 5. Create final hybrid forecast
final_hybrid_forecast = aligned_arimax_forecast + predicted_residuals.flatten()

# 6. Save to CSV
pred_df_hybrid = pd.DataFrame(final_hybrid_forecast, columns=['hybrid_pred'])
pred_df_hybrid.to_csv('hybrid_predictions.csv', index=False)

print("Hybrid predictions saved to 'hybrid_predictions.csv'")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# Hybrid predictions saved to 'hybrid_predictions.csv'
